# %%
import glob
import json
import numpy as np

# Get all nll results files
nll_files = glob.glob("nll_results_*.json")
nll_files = [f for f in nll_files if "_gt_True" not in f]
num_experts_per_tok = []
nlls = []
for f in nll_files:
    with open(f) as fp:
        data = json.load(fp)
        num_experts_per_tok.append(data["num_experts_per_tok"])
        nlls.append(data["mean_nll"])

sorted_indices = np.argsort(num_experts_per_tok)
sorted_nlls = [nlls[i] for i in sorted_indices]
sorted_num_experts_per_tok = [num_experts_per_tok[i] for i in sorted_indices]

for i in range(len(sorted_nlls)):
    print(f"{sorted_num_experts_per_tok[i]} experts per token, NLL: {sorted_nlls[i]}")
# Out:
# 1 experts per token, NLL: 9.17074892935609
# 2 experts per token, NLL: 0.7783004573245437
# 4 experts per token, NLL: 0.1364616621041905
# 6 experts per token, NLL: 0.09127384325597944
# 8 experts per token, NLL: 0.07864581178639753
# 10 experts per token, NLL: 0.08099631714312426
# 12 experts per token, NLL: 0.08741552150109755
# 14 experts per token, NLL: 0.09547159723790456
# 16 experts per token, NLL: 0.10499777479127223
# 20 experts per token, NLL: 0.12602176635259352
# 22 experts per token, NLL: 0.13657697425069398
# 24 experts per token, NLL: 0.14793261582406791

# %%
import glob
import json
import numpy as np

# Get all nll results files
nll_files = glob.glob("nll_results_*.json")
nll_files = [f for f in nll_files if "_gt_True" in f]
num_experts_per_tok = []
nlls = []
for f in nll_files:
    with open(f) as fp:
        data = json.load(fp)
        num_experts_per_tok.append(data["num_experts_per_tok"])
        nlls.append(data["mean_nll"])

sorted_indices = np.argsort(num_experts_per_tok)
sorted_nlls = [nlls[i] for i in sorted_indices]
sorted_num_experts_per_tok = [num_experts_per_tok[i] for i in sorted_indices]

for i in range(len(sorted_nlls)):
    print(f"{sorted_num_experts_per_tok[i]} experts per token, NLL: {sorted_nlls[i]}")
# Out:
# 1 experts per token, NLL: 10.022285265447142
# 2 experts per token, NLL: 1.8903682598552005
# 4 experts per token, NLL: 1.4317266046154467
# 6 experts per token, NLL: 1.4643066028702567
# 8 experts per token, NLL: 1.5015596440130903
# 10 experts per token, NLL: 1.5074554905497963
# 12 experts per token, NLL: 1.5048557235965783
# 14 experts per token, NLL: 1.5085883353673484
# 16 experts per token, NLL: 1.5019250069627281
# 20 experts per token, NLL: 1.493124747689084
# 22 experts per token, NLL: 1.4829993638542347
# 24 experts per token, NLL: 1.476668300798891

# %%
for i in sorted_nlls:
    print(i)
# Out:
# 10.022285265447142
# 1.8903682598552005
# 1.4317266046154467
# 1.4643066028702567
# 1.5015596440130903
# 1.5074554905497963
# 1.5048557235965783
# 1.5085883353673484
# 1.5019250069627281
# 1.493124747689084
# 1.4829993638542347
# 1.476668300798891

# %%
nlls = []
for f in nll_files:
    with open(f) as fp:
        data = json.load(fp)
        nlls.append(data["mean_nll"])
        
# Calculate statistics
mean_nll = np.mean(nlls)
std_nll = np.std(nlls)

print(f"Mean NLL across {len(nlls)} files: {mean_nll:.4f} ± {std_nll:.4f}")
print("\nIndividual NLLs:")
for i, nll in enumerate(nlls):
    print(f"File {i+1}: {nll:.4f}")
